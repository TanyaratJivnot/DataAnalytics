# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaratJivnot/DataAnalytics/blob/main/Data_Analytic(Tanyarat).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
# !pip install pymongo dnspython
# !pip install streamlit
from pymongo import MongoClient
from datetime import datetime
import pandas as pd

URI = 'mongodb+srv://botnoivoice:Botnoi1!@cluster0.1jgbr.mongodb.net/admin?retryWrites=true&w=majority'
client = MongoClient(URI)
database = client['prod-tts-payment']
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # Plot image with vector
pd.set_option('display.float_format','{:,.2f} '.format)
import seaborn as sns
import numpy as np

# %matplotlib inline
# ติดตั้งฟ้อนภาษาไทย
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
# !pip install -U --pre matplotlib  
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
documents = database.list_collection_names()
df = pd.DataFrame(documents)

df
# Out:
#                              0
# 0                     progress
# 1                        share
# 2                      coupons
# 3            use_invite_coupon
# 4                 voice_studio
# 5                     feedback
# 6         logs_error_get_voice
# 7   transfer_credits_statement
# 8          sales_withdraw_logs
# 9                     max_size
# 10                   blacklist
# 11                device_check
# 12                  dictionary
# 13           sound_sample_logs
# 14               alert_message
# 15               history_point
# 16            transfer_credits
# 17                pay_database
# 18                     speaker
# 19         generate_voice_link
# 20              logs_agreement
# 21                    aws_logs
# 22                       users
# 23                   whitelist
# 24                     package
# 25                      record
# 26                    sessions
# 27                     payment
# 28                  sales_data
# ...

# %% [markdown]
# # Looking Data Download

# %% [markdown]
# ## message Data

# %%
# ดึง data ตั้งแต่ 2022-11-01 ถึง 20xx-xx-xx
message = pd.DataFrame(list(database['message'].find( { 'datetime': {"$gt":"2023-05-01","$lt":"2023-05-02" }})))

# %%
message.head(5)
# Out:
#                         _id                            user_id  \
# 0  644e9e94f01730129865d70d       MCQ02KQyogcHRiZCTRpbwOE0e8K2
# 1  644e9e94a30ecd41c05556d0       h9O0P8nZDrdiE4VK1vge8hvzUqj1
# 2  644e9e9a5ed4b2ab6a739cf6       BAwiGrCO5dVrqALmjhj00YGU4uz1
# 3  644e9e9f7102cdfd92d6c4fd  U908a60196596b4bfebcb7fe49d72d6dd
# 4  644e9e9f4ef3bbfbc23a0d31  U65b08576ca15de0446856dc316ca9d8b
#
#                                              message channel count   speaker  \
# 0  สัมผัสกลิ่นรส หลงไหลความเข้มข้นของกาแฟดำ คงควา...    play   147       pla
# 1  อาวุธปืนสั้น 9 มม. Sigsauer M 1 8 จำนวน 20 กระ...    play    90   nopchai
# 2                             ชีวิตติดรำ by Grace ny    play    19   nopchai
# 3  องค์ประกอบที่2ด้านการปฏิบัติงาน1การจัดการเรียน...    play   222  tonkhaow
# 4                      ให้ตั้งนะโม3จบ แล้วกล่าวคำว่า    play    28       nid
#
#               datetime  url
# 0  2023-05-01 00:00:04  NaN
# 1  2023-05-01 00:00:04  NaN
# 2  2023-05-01 00:00:10  NaN
# ...

# %%
message.columns
# Out:
# Index(['_id', 'user_id', 'message', 'channel', 'count', 'speaker', 'datetime',
#        'url'],
#       dtype='object')

# %%
message.shape
# Out:
# (18896, 8)

# %%
len(message)
# Out:
# 18896

# %%
message.isna().sum()
# Out:
# _id             0
# user_id         0
# message         0
# channel         0
# count           0
# speaker         0
# datetime        0
# url         18715
# dtype: int64

# %% [markdown]
# ## users data

# %%
users = pd.DataFrame(list(database['users'].find()))

# %%
users.head(5)
# Out:
#                         _id                            user_id  \
# 0  613f706c082b44d43f4f81e5  U81901d7bdb0831777bfe3b5dfdeaadd7
# 1  6140a91d082b44d43f4f81e7  U682311b2261c43c35d9cfb4c0040d20b
# 2  6140bc51082b44d43f4f81ea  U493b213bf06fc60917bb17434581c384
# 3  61416b24fab439ae592bfc44  Ud0459a4310e6c7705f7424da1d15dadb
# 4  61469c87fab439ae592bfc46  U4c0eca7d983f06a926806d2c02ffd48f
#
#          username                      email  \
# 0     Bee.kmutnb🌻     beeminecraft@gmail.com
# 1     mig kasidis  wizhahe_dv_vb@hotmail.com
# 2          Qkuton       olindion@hotmail.com
# 3  Pattanun [Arm]    phattanun19@hotmail.com
# 4         P R A N       prandd.cnx@gmail.com
#
#                                                image  \
# 0  https://profile.line-scdn.net/0hZRlOiOe8BX1RNh...
# 1  https://profile.line-scdn.net/0hUvgAN1urCllaOB...
# 2  https://profile.line-scdn.net/0h0RjtbG9fb31XDX...
# 3  https://profile.line-scdn.net/0hBW_oHTWQHXhiFg...
# ...

# %%
users.columns
# Out:
# Index(['_id', 'user_id', 'username', 'email', 'image', 'jwt', 'start_datetime',
#        'end_datetime', 'credits', 'invite_code', 'token', 'sign_in_provider',
#        'agreement', 'personal_form', 'uid', 'account_status',
#        'last_login_type', 'subscription', 'play_quota', 'platform',
#        'sale_code_name', 'remember_password'],
#       dtype='object')

# %%
users.shape
# Out:
# (1331118, 22)

# %%
users.isna().sum()
# Out:
# _id                        0
# user_id                    0
# username                   5
# email                      0
# image                      0
# jwt                        0
# start_datetime             0
# end_datetime               0
# credits                    0
# invite_code              567
# token                1305466
# sign_in_provider      977674
# agreement             957090
# personal_form        1100568
# uid                  1100568
# account_status       1100568
# last_login_type       873388
# subscription         1280212
# play_quota           1280212
# platform              898858
# sale_code_name       1331099
# remember_password    1331118
# dtype: int64

# %% [markdown]
# ## payment Data

# %%
#get all data
payment = pd.DataFrame(list(database['payment'].find()))

# %%
payment = pd.DataFrame(list(database['payment']
                            .find({'datetime': {"$gt":"2023-02-01","$lt":"2023-03-22" }})))

# %%
payment.tail(4)
# Out:
#                             _id                            user_id  \
# 45192  641a41262d56e125be1a6b70  U033d6cdd40930ae3faa3ac8692f4f782
# 45193  641a414ecf58e28c4fbd3a46  U4ce90321a5f3c13b927ccd5d4ed79835
# 45194  641a420cccaf5bf2368c134c  U5e07dd7cde8b53d0c6bd171071cf3621
# 45195  641a43243fe69660b964ed8a  U5e07dd7cde8b53d0c6bd171071cf3621
#
#         package_id point price promotion  \
# 45192      credits   115     2         0
# 45193  package_100  5000   100       400
# 45194      credits   111     2         0
# 45195      credits   140     2         0
#
#                                                   qrcode  \
# 45192  00020101021230820016A0000006770101120115010753...
# 45193  00020101021230820016A0000006770101120115010753...
# 45194  00020101021230820016A0000006770101120115010753...
# 45195  00020101021230820016A0000006770101120115010753...
#
#                                            transactionid             datetime  \
# ...

# %% [markdown]
# ## speaker Data

# %%
speaker = pd.DataFrame(list(database['speaker'].find()))

# %%
speaker.drop(columns = ['image','face_image','horizontal_face_image','square_image','audio']).head(3)
# Out:
#                         _id speaker_id speaker_name eng_name thai_name  \
# 0  62e17c8fa082c5442d496a9a          6          pla    Siren     ไซเรน
# 1  62e17c8fa082c5442d496a9b          8          ati    Alisa     อลิสา
# 2  62e17c8fa082c5442d496a9c          9          max      Leo      เลโอ
#
#                     voice_style   age_style                     speech_style  \
# 0  [เสียงตื่นเต้น, เสียงมั่นใจ]     วัยรุ่น  [สไตล์เล่าเรื่อง, สไตล์ตัวละคร]
# 1                 [เสียงน่ารัก]     วัยรุ่น   [สไตล์เล่าเรื่อง, สไตล์บรรยาย]
# 2  [เสียงตื่นเต้น, เสียงมั่นใจ]  วัยผู้ใหญ่  [สไตล์อ่านข่าว, สไตล์สปอตโฆษณา]
#
#      speed popularity  type language  status   gender private allow_uid
# 0  พูดเร็ว    ยอดนิยม     0       TH    True  ผู้หญิง     NaN       NaN
# 1  พูดกลาง          -     1       TH    True  ผู้หญิง     NaN       NaN
# 2  พูดเร็ว          -     1       TH    True   ผู้ชาย     NaN       NaN

# %% [markdown]
# ## coupons Data

# %%
coupons = pd.DataFrame(list(database['coupons'].find()))

# %%
coupons.head(3)
# Out:
#                         _id     coupon_name  point  minimum  \
# 0  6139d4182feb7522f4b0f557          TWENTY     20        0
# 1  618ddb117bf6faeb7d823326     BNVWORKSHOP   2500        0
# 2  613b080719f9bf0aa299cb5a  BOTNOIPOINT500    500        0
#
#             start_time  uses timestamp
# 0  2021-09-30 23:19:13     0       NaN
# 1  2021-09-30 23:19:13     0       NaN
# 2  2021-09-30 23:19:13     0       NaN

# %% [markdown]
# ## Save to GG Drive

# %%
message.to_pickle('/content/drive/MyDrive/Botnoi/data/message_2023.png')

# %%
users.to_pickle('/content/drive/MyDrive/Botnoi/data/user.p')

# %%
payment.to_pickle('/content/drive/MyDrive/Botnoi/data/payments_df.p')

# %%
speaker.to_pickle('/content/drive/MyDrive/Botnoi/data/speaker_df.p')

# %% [markdown]
# # ตั้งคำถามเเละสมมุติฐาน

# %% [markdown]
# # Streamlit

# %%
# !pip install streamlit
import streamlit as st
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
